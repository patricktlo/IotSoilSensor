# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
R = [10e3]

C = np.linspace(300e-12, 5e-9, 200)

tau = R*C

plt.plot(C*1e9,tau*1e6)
plt.xlabel("Capacitance (nF)")
plt.ylabel("tau (us)")
# Out:
# Text(0,0.5,'tau (us)')
